# %%
pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.4.0-py3-none-any.whl.metadata (38 kB)
# Collecting kagglesdk<1.0,>=0.1.14 (from kagglehub)
#   Downloading kagglesdk-0.1.15-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in c:\users\paras\anaconda3\lib\site-packages (from kagglehub) (24.1)
# Requirement already satisfied: pyyaml in c:\users\paras\anaconda3\lib\site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in c:\users\paras\anaconda3\lib\site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\paras\anaconda3\lib\site-packages (from kagglehub) (4.66.5)
# Requirement already satisfied: protobuf in c:\users\paras\anaconda3\lib\site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (5.29.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\paras\anaconda3\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\paras\anaconda3\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\paras\anaconda3\lib\site-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\paras\anaconda3\lib\site-packages (from requests->kagglehub) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\paras\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-0.4.0-py3-none-any.whl (69 kB)
# Downloading kagglesdk-0.1.15-py3-none-any.whl (160 kB)
# Installing collected packages: kagglesdk, kagglehub
#
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    -------------------- ------------------- 1/2 [kagglehub]
#    ---------------------------------------- 2/2 [kagglehub]
#
# Successfully installed kagglehub-0.4.0 kagglesdk-0.1.15
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
import os

# %%
import kagglehub
import os
import pandas as pd

path = kagglehub.dataset_download("navoneel/brain-mri-images-for-brain-tumor-detection")
print("Dataset path:", path)


image_paths = []
labels = []

for label in ["yes", "no"]:
    folder = os.path.join(path, label)
    for file in os.listdir(folder):
        if file.endswith((".jpg", ".jpeg", ".png")):  
            image_paths.append(os.path.join(folder, file))
            labels.append(label)

df = pd.DataFrame({
    "image_path": image_paths,
    "label": labels
})

print(df.head())
print("Total samples:", len(df))
# Out:
# Dataset path: C:\Users\PARAS\.cache\kagglehub\datasets\navoneel\brain-mri-images-for-brain-tumor-detection\versions\1
#                                           image_path label
# 0  C:\Users\PARAS\.cache\kagglehub\datasets\navon...   yes
# 1  C:\Users\PARAS\.cache\kagglehub\datasets\navon...   yes
# 2  C:\Users\PARAS\.cache\kagglehub\datasets\navon...   yes
# 3  C:\Users\PARAS\.cache\kagglehub\datasets\navon...   yes
# 4  C:\Users\PARAS\.cache\kagglehub\datasets\navon...   yes
# Total samples: 179

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_gen = datagen.flow_from_directory(
    path,
    target_size=(128,128),
    batch_size=32,
    class_mode='binary',
    subset='training'
)

val_gen = datagen.flow_from_directory(
    path,
    target_size=(128,128),
    batch_size=32,
    class_mode='binary',
    subset='validation'
)
# Out:
# Found 406 images belonging to 3 classes.
# Found 100 images belonging to 3 classes.

# %%
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(128,128,3)),
    MaxPooling2D(pool_size=(2,2)),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
# Out:
# C:\Users\PARAS\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(train_gen, validation_data=val_gen, epochs=10)

loss, acc = model.evaluate(val_gen)
print("Validation Accuracy:", acc)
# Out:
# C:\Users\PARAS\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 659ms/step - accuracy: 0.1998 - loss: 0.8641 - val_accuracy: 0.1900 - val_loss: 0.3703
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 0.1973 - loss: 0.5357 - val_accuracy: 0.1900 - val_loss: 0.3604
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - accuracy: 0.1892 - loss: 0.6074 - val_accuracy: 0.1900 - val_loss: 0.3401
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step - accuracy: 0.1870 - loss: 0.5382 - val_accuracy: 0.1900 - val_loss: 0.3958
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step - accuracy: 0.1886 - loss: 0.4798 - val_accuracy: 0.1900 - val_loss: 0.4174
# Epoch 6/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - accuracy: 0.1959 - loss: 0.5289 - val_accuracy: 0.1900 - val_loss: 0.4496
# Epoch 7/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.1997 - loss: 0.5307 - val_accuracy: 0.1900 - val_loss: 0.4180
# Epoch 8/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.1595 - loss: 0.3688 - val_accuracy: 0.1900 - val_loss: 0.4554
# Epoch 9/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - accuracy: 0.1948 - loss: 0.5468 - val_accuracy: 0.1900 - val_loss: 0.5496
# Epoch 10/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - accuracy: 0.2054 - loss: 0.4836 - val_accuracy: 0.1900 - val_loss: 0.5727
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1854 - loss: 0.5847
# Validation Accuracy: 0.1899999976158142
